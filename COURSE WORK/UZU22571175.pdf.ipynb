# %% [markdown]
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:180%;text-align:center;border-radius:20px 60px;"> [MICRO_CLIMATE DATASET OVERVIEW]()</p>
# This is environmental data collected from multiple sensors in a strawberry greenhouse. Here's a breakdown of the columns:
# EnqueuedTimeUtc: This column serves as the index and represents the timestamp when the data was recorded.
# deviceId: This column represents the identifier of the sensor that collected the data.
# humidity: This column represents the air humidity percentage at the time of recording.
# temparature: This column represents the air temperature (in degrees Celsius) at the time of recording.
# irTemparature: This column represents the infrared temperature, which is a measure of leaf temperature (in degrees Celsius), at the time of recording. Here are a few observations from the provided data:
# Timestamps: The data spans multiple timestamps, indicating that measurements were taken at regular intervals.
# Sensor Identifier: Each observation is associated with a specific sensor identifier (deviceId), suggesting that multiple sensors were deployed to collect data.
# Environmental Parameters: The dataset includes measurements of air humidity, air temperature, and infrared temperature (as a proxy for leaf temperature), providing insights into the environmental conditions within the greenhouse. Variability: There appears to be variability in the environmental parameters across different timestamps and sensors, as indicated by the different values recorded for humidity, air temperature, and infrared temperature.
#
#
#    <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[TABLE OF CONTENTS]()</p>
#
# * [1. IMPORTING LIBRARIES](#1)
#
# * [2. LOADING DATA](#2)
#
# * [3. EXPLORATORY DATA ANALYSIS](#3)
#
#     * [3.1 Displaying the Initial Data Snapshot](#3.1)
#     * [3.2 Data Types](#3.2)
#     * [3.3 Data Types and Missing Values Overview](#3.3)
#     * [3.4 Summary Statistics Overview](#3.4)
#     * [3.5 Convert Timestamp to Datetime and Set Timestamp as Index](#3.5)
#     * [3.6 Converting Numeric Columns to Numeric Types](#3.6)
#     * [3.7 Plotting Time Series Analysis of Temperature, Humidity, and Infrared Temperature](#3.7)
#     * [3.8 Pairwise Relationship Analysis with Kernel Density Estimates](#3.8)
#     * [3.9 Boxplot Analysis of Temperature, Humidity, and Infrared Temperature](#3.9)
#     * [3.10  Histogram Analysis of Temperature, Humidity, and Infrared Temperature](#3.10)
#     * [3.11 Correlation Analysis and Heatmap Visualization](#3.11)
#     * [3.12 Visualizing Daily Mean Microclimate Variables](#3.12)
#     * [3.13 Seasonal Decomposition of Temperature Time Series](#3.13)
#
#
# * [4. RESEARCH QUESTIONS](#4)
#
#     * [4.1 RESEARCH QUESTION 2 : How do microclimate conditions vary throughout the day in the strawberry greenhouse?](#3.2)
#     * [4.2 RESEARCH QUESTION 3 : What is the spatial variability of microclimate conditions within the greenhouse?](#4.3)
#
#     * [4.3 RESEARCH QUESTION 3 : Are there correlations between air temperature, humidity, and infrared temperature in the greenhouse environment?](#4.4)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('./Micro_Climate.csv')  # Assuming 'microclimate_dataset.csv' is the name of your dataset file

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[EXPLORATORY DATA ANALYSIS]()</p>

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.1 Displaying the Initial Data Snapshot]()</p>

# %%
# Display the first few rows of the dataset
print(df.head())
# Out:
#        EnqueuedTimeUtc deviceId  humidity  temparature  irTemparature
# 0  16/02/2023 13:41:57  290EC1B        83           14             10
# 1  16/02/2023 13:41:57  290EF53        83           14             12
# 2  16/02/2023 13:41:58  290F190        88           13             12
# 3  16/02/2023 13:41:59  290F39C        84           13             11
# 4  16/02/2023 13:41:59  290F362        89           12             11

# %% [markdown]
# This is environmental data collected from multiple sensors in a strawberry greenhouse. Here's a breakdown of the columns:
#
# **EnqueuedTimeUtc:** This column serves as the index and represents the timestamp when the data was recorded.
#
# **deviceId:** This column represents the identifier of the sensor that collected the data.
#
# **humidity:** This column represents the air humidity percentage at the time of recording.
#
# **temparature:** This column represents the air temperature (in degrees Celsius) at the time of recording.
#
# **irTemparature:** This column represents the infrared temperature, which is a measure of leaf temperature (in degrees Celsius), at the time of recording.
# Here are a few observations from the provided data:
#
# **Timestamps:** The data spans multiple timestamps, indicating that measurements were taken at regular intervals.
#
# **Sensor Identifier:** Each observation is associated with a specific sensor identifier (deviceId), suggesting that multiple sensors were deployed to collect data.
#
# **Environmental Parameters:** The dataset includes measurements of air humidity, air temperature, and infrared temperature (as a proxy for leaf temperature), providing insights into the environmental conditions within the greenhouse.
# Variability: There appears to be variability in the environmental parameters across different timestamps and sensors, as indicated by the different values recorded for humidity, air temperature, and infrared temperature.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.2 Data Types]()</p>

# %%
# Check the data types and missing values
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371079 entries, 0 to 371078
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   EnqueuedTimeUtc  371079 non-null  object
#  1   deviceId         371079 non-null  object
#  2   humidity         371079 non-null  int64
#  3   temparature      371079 non-null  int64
#  4   irTemparature    371079 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 14.2+ MB
# None

# %% [markdown]
# **Dataframe Information:**
# The dataset comprises a total of 371,079 entries and 5 columns.
# Each row represents a specific observation captured by the MicroClimate sensors.
#
# The dataset contains the following columns:
# **EnqueuedTimeUtc:** Represents the date and time when the observation was recorded.
#
# **deviceId:** Acts as a unique identifier for the sensor that generated the observation.
#
# **humidity:** Indicates the air humidity percentage at the time of observation.
#
# **temparature:** Represents the air temperature recorded at the time of observation.
#
# **irTemparature:** Denotes the infrared temperature, serving as a measure of leaf temperature.
#
# The data types of the columns include integers (int64) and objects (object), with the latter likely representing string or categorical data.
#
# **Data Quality:**
# The analysis indicates that there are no missing values (Non-Null Count) in any of the columns, suggesting a relatively complete dataset.
#
# **Memory Usage:**
# The memory usage of the dataset is reported to be approximately 14.2 MB, indicating a moderate-sized dataset.
# This information is useful for understanding the computational resources required for processing and analyzing the dataset efficiently.
#
# **Column Information:**
# The column names and their corresponding descriptions provide valuable context for understanding the dataset's contents.
# The presence of essential environmental variables such as humidity, air temperature, and infrared temperature highlights the dataset's relevance for studying microclimatic conditions.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.3 Data Types and Missing Values Overview]()</p>

# %%
# Check for missing values
missing_values = df.isnull().sum()
# Print the missing values count for each column
print("Missing values count for each column:")
print(missing_values)
# Check if there are any missing values in the entire dataset
if missing_values.any():
    print("\nThere are missing values in the dataset.")
else:
    print("\nNo missing values found in the dataset.")
# Out:
# Missing values count for each column:
# EnqueuedTimeUtc    0
# deviceId           0
# humidity           0
# temparature        0
# irTemparature      0
# dtype: int64
#
# No missing values found in the dataset.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.4 Summary Statistics Overview]()</p>

# %%
# Summary statistics
print(df.describe())
# Out:
#             humidity    temparature  irTemparature
# count  371079.000000  371079.000000  371079.000000
# mean       70.233212      10.857437      14.718577
# std        27.817407       6.505052      15.454556
# min         0.000000     -40.000000     -40.000000
# 25%        69.000000       8.000000       9.000000
# 50%        80.000000      11.000000      12.000000
# 75%        86.000000      15.000000      18.000000
# max       100.000000      31.000000      59.000000

# %% [markdown]
# The provided analysis presents summary statistics for three key environmental variables recorded in the MicroClimate dataset: humidity, air temperature, and infrared temperature (as a measure of leaf temperature). Below is the analysis of the given summary statistics:
#
# **Humidity:**
# The mean humidity across all observations is approximately 70.23%, indicating a moderate level of moisture in the air within the strawberry greenhouse.
# The standard deviation of humidity is approximately 27.82%, suggesting a considerable degree of variability in humidity levels within the dataset.
# The minimum humidity recorded is 0%, which may indicate instances of extremely dry conditions or potential measurement errors.
# The maximum humidity recorded is 100%, indicating instances of saturation or high humidity levels, which could occur during periods of intense watering or high external humidity.
#
# **Air Temperature:**
# The mean air temperature across all observations is approximately 10.86°C, representing a relatively cool ambient temperature within the greenhouse.
# The standard deviation of air temperature is approximately 6.51°C, indicating variability in temperature readings throughout the dataset.
# The minimum recorded air temperature is -40°C, which may be an outlier or an indication of erroneous data.
# The maximum recorded air temperature is 31°C, suggesting instances of warmer conditions within the greenhouse, potentially influenced by external factors or heating systems.
#
# **Infrared Temperature (Leaf Temperature):**
# The mean infrared temperature, serving as a proxy for leaf temperature, is approximately 14.72°C, indicating slightly higher temperatures compared to ambient air temperature.
# The standard deviation of infrared temperature is relatively high at approximately 15.45°C, suggesting significant variability in leaf temperature readings.
# Similar to air temperature, the minimum and maximum recorded infrared temperatures are -40°C and 59°C, respectively. These extreme values may warrant further investigation to determine their validity and potential impact on the dataset's integrity.

# %% [markdown]
# Convert Timestamp to Datetime
# Set Timestamp as Index
#
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.5 Convert Timestamp to Datetime and Set Timestamp as Index]()</p>

# %%
# Convert EnqueuedTimeUtc to datetime
df['EnqueuedTimeUtc'] = pd.to_datetime(df['EnqueuedTimeUtc'])

# Set EnqueuedTimeUtc as index
df.set_index('EnqueuedTimeUtc', inplace=True)
# Out:
# <ipython-input-17-3929765d880f>:2: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['EnqueuedTimeUtc'] = pd.to_datetime(df['EnqueuedTimeUtc'])

# %% [markdown]
# **Conversion to datetime format:** The code successfully converts the 'EnqueuedTimeUtc' column to datetime format, which is essential for conducting time-series analysis. By converting the timestamp data into datetime objects, it becomes easier to perform various operations such as filtering by date, resampling, and plotting time-series data.
#
# **Setting the datetime column as the index:** Setting the 'EnqueuedTimeUtc' column as the index of the DataFrame is a common practice in time-series analysis. This allows for efficient indexing and retrieval of data based on timestamps. It also facilitates the use of pandas' powerful datetime indexing capabilities, such as resampling and time-based slicing.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.6 Converting Numeric Columns to Numeric Types]()</p>

# %%
# Convert numeric columns to numeric types
numeric_cols = ['temparature', 'humidity', 'irTemparature']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.7 Plotting Time Series Analysis of Temperature, Humidity, and Infrared Temperature]()</p>

# %%
# Plotting temperature, humidity, and infrared temperature over time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['temparature'], label='Temperature', color='blue')
plt.plot(df.index, df['humidity'], label='Humidity', color='green')
plt.plot(df.index, df['irTemparature'], label='Infrared Temperature', color='red')
plt.xlabel('Time')
plt.ylabel('Values')
plt.title('Time Series Analysis of Temperature, Humidity, and Infrared Temperature')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Data Description:**
# This displays a time series graph that plots three variables over time: Temperature (in blue), Humidity (in green), and Infrared Temperature (in red). The X-axis represents time, spanning from March 2023 to January 2024, and the Y-axis represents the values for each variable but without a clear indication of the units of measurement. The data points for Temperature and Infrared Temperature are connected by lines, while the Humidity appears as a filled area chart.
# **Result of Analysis:**
# From the graph, we can observe the following trends and patterns:
# Temperature seems relatively stable, with minor fluctuations. There is a noticeable dip around mid-March, where the temperature goes below zero (assuming the unit is Celsius or a similar scale). After this dip, the temperature appears to rise slightly before leveling off.
#
# Humidity displays a stable pattern until late August, where it drops precipitously. After this drop, it seems to recover somewhat but then falls again in October, reaching negative values. There is a recovery indicated in late October, with values reaching the highest point on the graph.
#
# Infrared Temperature shows significant variability, with the values ranging widely. It seems to maintain very high levels most of the time, indicated by the red area occupying the upper portion of the graph. There is a sharp drop in Infrared Temperature around mid-August, and again in mid-October, where the values become negative.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.8 Pairwise Relationship Analysis with Kernel Density Estimates]()</p>

# %%
sns.pairplot(df, diag_kind='kde')
plt.show()

# %% [markdown]
# This show a matrix of scatter plots and histograms, which is a form of a pair plot used to understand the relationship between different variables in a dataset. The three variables involved are humidity, temperature, and irTemperature (infrared temperature).
#
# **Histograms:** These are on the diagonal of the matrix and they show the distribution of a single variable. The histograms for humidity, temperature, and irTemperature each show how frequently values occur within a certain range for that specific variable.
#
# **Scatter Plots:** These plots are off the diagonal and depict the relationship between two variables. Each point on a scatter plot represents an observation in the dataset with its position determined by the two variables it represents.
#
# **Result of Analysis:**
#
# **Histogram of Humidity:** This histogram shows a bimodal distribution with two peaks, suggesting there are two common ranges where humidity values are clustered.
#
# **Histogram of Temperature:** It shows a wide range of temperatures with the majority of data points concentrated around a central peak, indicating a common temperature range where most values are found.
#
# **Histogram of irTemperature:** The distribution is somewhat bimodal, with a primary peak and a smaller secondary peak to the right, suggesting two ranges where infrared temperature measurements are more common.
#
# **Scatter Plot of Humidity vs. Temperature:** There is a dense clustering of points that appears to show a negative correlation, indicating that as temperature increases, humidity tends to decrease.
#
# **Scatter Plot of Humidity vs. irTemperature:** This plot also shows a dense clustering, with a somewhat negative correlation similar to the temperature vs. humidity plot.
#
# **Scatter Plot of Temperature vs. irTemperature:** This shows a strong positive correlation, indicating that as the temperature increases, the infrared temperature also tends to increase.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.9 Boxplot Analysis of Temperature, Humidity, and Infrared Temperature]()</p>

# %%
# Boxplot for temperature, humidity, and infrared temperature
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['temparature', 'humidity', 'irTemparature']])
plt.title('Boxplot of Temperature, Humidity, and Infrared Temperature')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# This is Boxplot of Temperature, Humidity, and Infrared Temperature.
#
#  **Here are the key points:**
#
# **Temperature:**
# The temperature data has values ranging approximately from -20 to 20.
# The median temperature value is around 0.
# The interquartile range (IQR) for temperature is represented by the box in the plot.
#
# **Humidity:**
# The humidity data spans a range roughly from 20 to 80.
# The median humidity value is approximately 60.
# Similar to temperature, the IQR for humidity is shown by the box.
#
# **Infrared Temperature:**
# The infrared temperature values span from about -40 to 100.
# The median infrared temperature value is close to 50.
# Outliers are present in both the humidity and infrared temperature data, indicated by individual points outside the whiskers.
# Overall, this boxplot provides a visual comparison of these three variables: temperature, humidity, and infrared temperature. It helps us understand their distributions and central tendencies.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.10 Histogram Analysis of Temperature, Humidity, and Infrared Temperature]()</p>

# %%
# Histograms for temperature, humidity, and infrared temperature
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.histplot(df['temparature'], kde=True, color='blue')
plt.title('Temperature Distribution')

plt.subplot(1, 3, 2)
sns.histplot(df['humidity'], kde=True, color='green')
plt.title('Humidity Distribution')

plt.subplot(1, 3, 3)
sns.histplot(df['irTemparature'], kde=True, color='red')
plt.title('Infrared Temperature Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observed Insights**
#
#
# **Temperature Distribution:**
# The blue line represents the temperature distribution.
# Most counts are concentrated around 0 degrees.
# This suggests that the majority of measurements fall near the freezing point.
# There are relatively fewer measurements at higher temperatures.
#
# **Humidity Distribution:**
# The green line represents the humidity distribution.
# The peak occurs around 40% humidity.
# This indicates that the data is centered around moderate humidity levels.
# The distribution is more spread out compared to the temperature distribution.
#
# **Infrared Temperature Distribution:**
# The red line represents the infrared temperature distribution.
# There are two peaks:
# A sharp peak near 0 degrees (similar to the temperature distribution).
# A broader peak around 20 degrees.
# This suggests that there are two distinct groups of measurements.
# The broader peak indicates a wider range of infrared temperatures.
# In summary, the graph provides insights into the distributions of temperature, humidity, and infrared temperature. Most measurements are clustered around specific values, but there are variations in each distribution.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.11 Correlation Analysis and Heatmap Visualization]()</p>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Step 2: Drop any non-numeric or irrelevant columns
df_numeric = df[['temparature', 'humidity', 'irTemparature']]  # Select only numeric columns

# Step 3: Convert remaining non-numeric columns to numeric types
df_numeric = df_numeric.apply(pd.to_numeric, errors='coerce')  # Convert to numeric, coercing errors to NaN

# Step 4: Calculate the correlation matrix and plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **Here are the insights**
#
#
# **Correlation Heatmap:**
# The graph represents a correlation heatmap showing the relationships between three variables: temperature, humidity, and irTemperature.
# Each cell in the heatmap contains a numerical value representing the correlation coefficient between the corresponding pair of variables.
#
# The color scale indicates the strength of the correlation: red for positive correlations and blue for negative correlations.
#
# Correlation Coefficients:
#
# **Temperature:**
# Correlation with itself: 1.00 (perfect positive correlation, as expected).
# Correlation with humidity: 0.52 (moderate positive correlation).
# Correlation with irTemperature: -0.04 (very weak negative correlation).
#
# **Humidity:**
# Correlation with temperature: 0.52 (moderate positive correlation).
# Correlation with itself: 1.00 (perfect positive correlation).
# Correlation with irTemperature: -0.31 (weak negative correlation).
#
# **irTemperature:**
# Correlation with temperature: -0.04 (almost no linear relationship).
# Correlation with humidity: -0.31 (weak inverse relationship).
# Correlation with itself: 1.00 (perfect positive correlation).
#
#
# **Interpretation:**
# The strong positive correlation between temperature and itself is expected.
# The moderate positive correlation between temperature and humidity suggests that as temperature increases, humidity tends to increase as well.
# The weak negative correlation between temperature and irTemperature indicates almost no linear relationship.
# Similarly, the weak inverse correlation between humidity and irTemperature suggests that they are not strongly related.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.12 Visualizing Daily Mean Microclimate Variables]()</p>

# %%
# Ensure datetime index
df.index = pd.to_datetime(df.index)

# Selecting only numeric columns
df_numeric = df[['temparature', 'humidity', 'irTemparature']]

# Resample data by day and visualize
df_numeric.resample('D').mean().plot(subplots=True, figsize=(10, 8))
plt.show()

# %% [markdown]
# **Graph Description:**
# The graph consists of three separate line plots stacked vertically.
# Each plot represents a different parameter over time: temperature, humidity, and irTemperature.
# The x-axis represents time, spanning from March to December 2023.
# The y-axis values differ for each parameter.
#
# **Temperature (Blue Line):**
# The temperature graph shows fluctuations.
# There is a general upward trend in temperature values as time progresses.
#
# **Humidity (Orange Line):**
# The humidity graph displays a sharp drop at the beginning.
# Subsequently, it fluctuates at lower levels with occasional spikes.
#
# **irTemperature (Green Line):**
# The irTemperature graph has sparse data points.
# It exhibits significant drops and rises.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[3.13 Seasonal Decomposition of Temperature Time Series]()</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Assuming you have already loaded your dataset into a DataFrame named 'df'

# Convert temperature column to numeric, coercing errors to NaN
df['temparature'] = pd.to_numeric(df['temparature'], errors='coerce')

# Drop rows with NaN values in the temperature column
df.dropna(subset=['temparature'], inplace=True)

# Seasonal decomposition plot
decomposition = seasonal_decompose(df['temparature'], period=30)  # Assuming a seasonal period of 30 days

plt.figure(figsize=(12, 8))

# Plotting the original time series
plt.subplot(411)
plt.plot(df.index, df['temparature'], label='Original', color='blue')
plt.legend(loc='upper left')

# Plotting the trend component
plt.subplot(412)
plt.plot(df.index, decomposition.trend, label='Trend', color='green')
plt.legend(loc='upper left')

# Plotting the seasonal component
plt.subplot(413)
plt.plot(df.index, decomposition.seasonal, label='Seasonal', color='red')
plt.legend(loc='upper left')

# Plotting the residual component
plt.subplot(414)
plt.plot(df.index, decomposition.resid, label='Residual', color='gray')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Original Graph:**
# The “Original” graph blue lines(top) exhibits sharp fluctuations, with a significant drop toward the end of the timeline (around 2023-04).
# This suggests that the underlying data might be volatile or influenced by external factors.
#
# **Trend Graph:**
# The “Trend” graph shows green lines, indicating an overall trend extracted from the original data.
# Despite the fluctuations, there seems to be a gradual upward movement over time.
# This suggests a potential long-term growth pattern.
#
# **Seasonal Graph:**
# The “Seasonal” graph consists of red bars that oscillate around a baseline.
# These fluctuations imply seasonal variations in the data set.
# It’s possible that certain events or recurring patterns impact the data periodically.
#
# **Residual Graph:**
# The “Residual” graph displays gray bars.
# Residual values represent what remains after accounting for trend and seasonality.
# The stability of these residuals indicates that most of the variation has been explained by the trend and seasonal components.
# However, there’s a noticeable spike at the end of 2023-12, which might warrant further investigation.
# In summary:
# The original data is volatile, but there’s an upward trend.
# Seasonal effects play a role, and residuals are generally stable.
# Investigate the sudden spike in residuals at the end of 2023-12 to understand its cause.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[4.1 Research Question 1]()</p>

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[How do microclimate conditions vary throughout the day in the strawberry greenhouse?]()</p>

# %% [markdown]
# The aim is to understand the variations in microclimate conditions within the strawberry greenhouse. Specifically, to investigate how environmental factors such as temperature, humidity, and infrared temperature fluctuate over the course of a day.

# %% [markdown]
# We'll visualize the hourly variation in temperature

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("./Micro_Climate.csv")

# Convert EnqueuedTimeUtc to datetime
df['EnqueuedTimeUtc'] = pd.to_datetime(df['EnqueuedTimeUtc'])

# Set EnqueuedTimeUtc as index
df.set_index('EnqueuedTimeUtc', inplace=True)

# Hourly Mean Temperature Calculation
df['hour'] = df.index.hour
hourly_mean_temperature = df.groupby('hour')['temparature'].mean()

# Visualization
plt.figure(figsize=(10, 6))
sns.lineplot(x=hourly_mean_temperature.index, y=hourly_mean_temperature.values)
plt.title('Hourly Mean Temperature Variation')
plt.xlabel('Hour of the Day')
plt.ylabel('Mean Temperature (°C)')
plt.xticks(range(24))
plt.grid(True)
plt.show()
# Out:
# <ipython-input-29-7eba87749bb6>:9: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['EnqueuedTimeUtc'] = pd.to_datetime(df['EnqueuedTimeUtc'])

# %% [markdown]
# The graph represent the hourly mean temperature variation over a 24-hour period:
# The graph shows the following trends:
# The temperature peaks at around 14:00 (2 PM).
# It is at its lowest during the early hours of the morning.
# There is a sharp increase in temperature from early morning to afternoon.
# The temperature gradually decreases from afternoon to late evening.
#
#
# **Key observations**
# **Peak Temperature:** The highest temperature occurs around 14:00 (2 PM), suggesting that this is the warmest part of the day.
#
# **Morning Coolness:** The lowest temperatures are observed during the early morning hours, indicating cooler conditions.
#
# **Afternoon Heat:** There is a significant increase in temperature from morning to afternoon, likely due to solar heating.
#
# **Evening Cooling:** As the day progresses, the temperature gradually decreases, leading to cooler evenings.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[This is refined visualization for Research Question 1]()</p>

# %% [markdown]
# I've calculated the hourly mean humidity and infrared temperature alongside the temperature.
# The visualization now includes three lines representing mean temperature, mean humidity, and mean infrared temperature, providing a comprehensive view of the hourly microclimate variation.
# The lines are plotted with different colors and labeled accordingly for clarity.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("./Micro_Climate.csv")

# Convert EnqueuedTimeUtc to datetime
df['EnqueuedTimeUtc'] = pd.to_datetime(df['EnqueuedTimeUtc'])

# Set EnqueuedTimeUtc as index
df.set_index('EnqueuedTimeUtc', inplace=True)

# Hourly Mean Temperature Calculation
df['hour'] = df.index.hour
hourly_mean_temperature = df.groupby('hour')['temparature'].mean()

# Hourly Mean Humidity Calculation
hourly_mean_humidity = df.groupby('hour')['humidity'].mean()

# Hourly Mean Infrared Temperature Calculation
hourly_mean_ir_temperature = df.groupby('hour')['irTemparature'].mean()

# Visualization with multiple variables
plt.figure(figsize=(12, 8))

# Mean Temperature
plt.plot(hourly_mean_temperature.index, hourly_mean_temperature.values, label='Temperature (°C)', color='blue')

# Mean Humidity
plt.plot(hourly_mean_humidity.index, hourly_mean_humidity.values, label='Humidity (%)', color='green')

# Mean Infrared Temperature
plt.plot(hourly_mean_ir_temperature.index, hourly_mean_ir_temperature.values, label='Infrared Temperature (°C)', color='red')

plt.title('Hourly Microclimate Variation')
plt.xlabel('Hour of the Day')
plt.ylabel('Mean Value')
plt.xticks(range(24))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-30-a0084b919822>:9: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['EnqueuedTimeUtc'] = pd.to_datetime(df['EnqueuedTimeUtc'])

# %% [markdown]
# The graph is titled “Hourly Microclimate Variation.” Here are the insights based on the data it presents:
#
#
# **Temperature (°C):**
# The blue line represents temperature variation throughout the day.
# The temperature follows a diurnal pattern, with the highest values occurring around midday (approximately 12:00 to 14:00 hours).
# It gradually decreases during the evening and night hours.
# The lowest temperatures are observed in the early morning (around 06:00 to 08:00 hours).
#
# **Humidity (%):**
# The green line represents humidity levels.
# Humidity remains relatively constant throughout the day.
# There are minor fluctuations, but overall, it maintains a consistent value.
# This suggests that the microclimate has a stable moisture content.
#
# **Infrared Temperature (°C):**
# The red line represents infrared temperature.
# Similar to the regular temperature, the infrared temperature also follows a diurnal pattern.
# Peaks occur around midday, indicating higher surface temperatures.
# The lowest infrared temperatures are observed during the early morning and late evening.
#
# **Overall Observations:**
# The microclimate experiences daily temperature fluctuations, with daytime warmth and nighttime cooling.
# Humidity remains relatively stable, suggesting a consistent moisture environment.
# The infrared temperature closely mirrors the regular temperature, indicating similar surface conditions.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[4.2 Research Question 2]()</p>

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[What is the spatial variability of microclimate conditions within the greenhouse?]()</p>

# %% [markdown]
# The aim of this research question is to explore the spatial variability of microclimate conditions within the greenhouse. It seeks to understand how environmental factors such as temperature, humidity, and infrared temperature vary across different locations or zones within the greenhouse. By investigating spatial variability, researchers can identify hotspots or areas with unique microclimatic conditions that may influence plant growth and health. Understanding the spatial distribution of microclimate conditions is crucial for optimizing greenhouse layout, placement of sensors, and management practices to ensure uniform growing conditions for the plants throughout the greenhouse. Additionally, this analysis can provide valuable insights for improving crop yield and quality by addressing localized environmental challenges or opportunities within the greenhouse environment.

# %% [markdown]
# We'll visualize the mean temperature across different sensors in the greenhouse

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load the dataset
df = pd.read_csv("./Micro_Climate.csv")
data= df
# Step 2: Data Preprocessing
# Convert timestamp to datetime object
data['EnqueuedTimeUtc'] = pd.to_datetime(df['EnqueuedTimeUtc'])

# Step 3: Spatial Analysis - Mean Temperature Across Sensors
sensor_data = data.groupby('deviceId').mean()

# Step 4: Visualization
plt.figure(figsize=(10, 6))
sns.barplot(x=sensor_data.index, y='temparature', data=sensor_data)
plt.title('Mean Temperature Across Sensors')
plt.xlabel('Sensor ID')
plt.ylabel('Mean Temperature (°C)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# In this refined visualization:
#
# We've sorted the sensors based on mean temperature to easily identify the sensors with the highest and lowest temperatures.
# We've added color mapping to represent humidity along with temperature, providing insights into the relationship between temperature and humidity.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load the dataset
df = pd.read_csv("./Micro_Climate.csv")
data = df
# Step 2: Data Preprocessing
# Convert timestamp to datetime object
data['EnqueuedTimeUtc'] = pd.to_datetime(data['EnqueuedTimeUtc'])

# Step 3: Spatial Analysis - Mean Temperature Across Sensors
sensor_data = data.groupby('deviceId').mean()

# Step 4: Refine Visualization
# Sort sensors based on mean temperature
sensor_data = sensor_data.sort_values(by='temparature', ascending=False)

# Visualization
plt.figure(figsize=(12, 8))
sns.barplot(x=sensor_data.index, y='temparature', data=sensor_data, palette='coolwarm')
plt.title('Mean Temperature Across Sensors')
plt.xlabel('Sensor ID')
plt.ylabel('Mean Temperature (°C)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Adding additional variables (e.g., humidity) using hue
# Assuming 'humidity' column exists in sensor_data
sns.barplot(x=sensor_data.index, y='temparature', hue='humidity', data=sensor_data, palette='coolwarm', dodge=False)

# Show plot
plt.legend(title='Humidity')
plt.show()
# Out:
# <ipython-input-9-761699c8c017>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sensor_data.index, y='temparature', data=sensor_data, palette='coolwarm')

# %% [markdown]
# **Here are some insights from the graph:**
# Most sensors (except for one) show higher humidity levels. The orange and red bars indicate high level of humidity while the blue bars indicate low humidity level.
# Sensor 2909460, represented by the orange bar, has a higher humidity level.
# the temperature readings seem to vary across sensors, with some showing higher mean temperatures than others.
#
#
# **Temperature Variation:**
# The mean temperature readings across sensors vary significantly.
# Some sensors have higher mean temperatures (closer to 16°C), while others have lower mean temperatures (closer to 0°C).
#
# **Humidity Influence:**
# The color-coded bars indicate humidity levels.
# Most sensors (except for one) show higher humidity levels.
# Sensor 2909460 stands out with a higher humidity reading (orange bar).
#
#
# **Possible Observations:**
# Sensors with higher humidity tend to have slightly higher mean temperatures.
# Sensors with lower humidity tend to have slightly lower mean temperatures.
#
# **Overall Trend:**
# There isn’t a clear linear trend across all sensors.
# However, the combination of humidity and temperature readings suggests some correlation.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[4.3 Research Question 3]()</p>

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[Are there correlations between air temperature, humidity, and infrared temperature in the greenhouse environment?]()</p>

# %% [markdown]
# The aim of Research Question 3 is to investigate the correlations between air temperature, humidity, and infrared temperature in the greenhouse environment. This question seeks to understand the relationships and associations between these key microclimate variables.

# %% [markdown]
# We'll calculate the correlation matrix to identify any relationships between these variables.

# %%
import pandas as pd

# Step 1: Load the dataset
df = pd.read_csv("/Micro_Climate.csv")
data = df
# Step 2: Data Preprocessing
# Convert timestamp to datetime object
data['EnqueuedTimeUtc'] = pd.to_datetime(data['EnqueuedTimeUtc'])

# Step 3: Correlation Analysis
# Calculate correlations between variables
correlation_matrix = data[['temparature', 'humidity', 'irTemparature']].corr()

# Step 4: Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                temparature  humidity  irTemparature
# temparature       1.000000  0.515778      -0.037087
# humidity          0.515778  1.000000      -0.313932
# irTemparature    -0.037087 -0.313932       1.000000
# <ipython-input-33-53ec0a1eee37>:8: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['EnqueuedTimeUtc'] = pd.to_datetime(data['EnqueuedTimeUtc'])

# %% [markdown]
# **Correlation Matrix**
#
# **Temperature and Humidity:**
# There is a moderate positive correlation (0.515778) between temperature and humidity. This suggests that as temperature increases, humidity tends to increase as well, and vice versa. This relationship is expected as warmer air can hold more moisture, leading to higher humidity levels.
#
# **Temperature and Infrared Temperature (IR):**
# There is a weak negative correlation (-0.037087) between temperature and infrared temperature. This indicates that there is little to no linear relationship between the two variables. In other words, changes in air temperature do not significantly affect infrared temperature, and vice versa.
#
# **Humidity and Infrared Temperature (IR):**
# There is a moderate negative correlation (-0.313932) between humidity and infrared temperature. This suggests that as humidity increases, infrared temperature tends to decrease, and vice versa. Higher humidity levels may lead to cooler leaf temperatures, as moisture content affects the thermal properties of leaves.
# These insights provide valuable information about the relationships between temperature, humidity, and infrared temperature within the greenhouse environment.

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#6c617d;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">[This is refined visualization for research question 3 to get the graph of the Correlation Matrix]()</p>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load the dataset
df = pd.read_csv("./Micro_Climate.csv")
data = df
# Step 2: Data Preprocessing
# Convert timestamp to datetime object
data['EnqueuedTimeUtc'] = pd.to_datetime(data['EnqueuedTimeUtc'])

# Step 3: Correlation Analysis
# Calculate correlations between variables
correlation_matrix = data[['temparature', 'humidity', 'irTemparature']].corr()

# Step 4: Plot the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, square=True)
plt.title('Correlation Matrix of Microclimate Variables')
plt.show()
# Out:
# <ipython-input-34-0d6b1df975c7>:10: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['EnqueuedTimeUtc'] = pd.to_datetime(data['EnqueuedTimeUtc'])

# %% [markdown]
# The graph represents a color-coded correlation matrix for three variables: temperature, humidity, and infrared temperature (irTemperature).
# Each variable is correlated with itself (diagonal from top left to bottom right), showing a perfect positive correlation of 1.00 (as expected).
#
# **Key correlations:**
# Temperature and humidity have a positive correlation of 0.52, suggesting that as temperature increases, humidity tends to increase as well.
# Temperature has a slightly negative correlation with irTemperature at -0.04, indicating almost no linear relationship between them.
# Humidity has a negative correlation with irTemperature at -0.31, suggesting that as humidity increases, irTemperature tends to decrease slightly.
# The color scale ranges from red (positive correlations) through white (neutral) to blue (negative correlations).
#
# **Interpretation:**
# The positive correlation between temperature and humidity implies that higher temperatures are associated with increased humidity levels.
# The weak negative correlation between temperature and irTemperature suggests that they are largely independent of each other.
# The negative correlation between humidity and irTemperature indicates that higher humidity tends to be associated with slightly lower irTemperature readings.
